# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_csv('train.csv')

# %%
data=data.drop(['Id'],axis=1)

# %%
data['Edad'].fillna(value=data['Edad'].median(),inplace=True)

# %%
data['Pais'].fillna(method='ffill',inplace=True)

# %%
data['Niños'].fillna(method='ffill',inplace=True)

# %% [markdown]
# # Removing categorical labels

# %%
le = preprocessing.LabelEncoder()
data['Genero']=le.fit_transform(data['Genero'])

# %%
data['Pais']=le.fit_transform(data['Pais'])

# %%
data['Acomodacion']=le.fit_transform(data['Acomodacion'])

# %%
data = data.astype({"Edad":'int', "Niños":'int'})

# %% [markdown]
# # Split the data

# %%
columns = ['Dias', 'Genero', 'Edad', 'Niños', 'Pais']
x = data[columns]
y = data.Acomodacion

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size = 0.2, random_state=0)

# %% [markdown]
# # Train the model

# %%
model = MultinomialNB()
model.fit(X_train,Y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# # Evaluate the model

# %%
Y_pred = model.predict(X_test)

# %%
cnf = metrics.confusion_matrix(Y_test,Y_pred)
cnf
# Out:
# array([[   0,  848],
#        [   0, 1126]])

# %%
model.score(X_test,Y_test)
# Out:
# 0.5704154002026343

# %% [markdown]
# ### The model always return 1.
